# %%
from PCA_and_ETC import *

import Clustering as C

# %%
warnings.filterwarnings("ignore")
file = '2002-08.csv'
input_dir = '../Database/characteristics_US'

# %%
K_mean_Plot = True
if K_mean_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_kmeans(100)

    plot_UMAP(df_combined, Do_Clustering.K_Mean_labels)

# %%
DBSCAN_Plot = True
if DBSCAN_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_DBSCAN(0.9)

    plot_UMAP(df_combined, Do_Clustering.DBSCAN_labels)

# %%
Agglormerative_Plot = True
if Agglormerative_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_HA(0.9)

    plot_UMAP(df_combined, Do_Clustering.Agglomerative_labels)

# %%
Contrastive_Plot = False
if Contrastive_Plot:
    data = read_and_preprocess_data(input_dir, file)
    
    base_directory = f'../Database/Clustering_Result/Contrastive_Learning/100_characteristics_us_batch_64_bins_32_hidden_128'
    data = read_and_preprocess_data(base_directory, file)
    
    Contrastive_labels = []
    for i, label in enumerate(data['clusters']):
        # if label-1 == 0:
        #     Contrastive_labels.append(-1)
        Contrastive_labels.append(label-1)
        
    Contrastive_labels = np.array(Contrastive_labels)
    plot_UMAP(data, Contrastive_labels)

# %%
Bisecting_Plot = False
if Bisecting_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.bisecting_K_mean(10)

    plot_UMAP(df_combined, Do_Clustering.bisecting_K_mean_labels)

# %%
HDBSCAN_Plot = False
if HDBSCAN_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_HDBSCAN(0.5)

    plot_UMAP(df_combined, Do_Clustering.HDBSCAN_labels)

# %%
BIRCH_Plot = False
if BIRCH_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_BIRCH(0.5)

    plot_UMAP(df_combined, Do_Clustering.BIRCH_labels)

# %%
OPTICS_Plot = False
if OPTICS_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_OPTICS(0.5)

    plot_UMAP(df_combined, Do_Clustering.OPTIC_labels)

# %%
meanshift_Plot = False
if meanshift_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_meanshift(0.9)

    plot_UMAP(df_combined, Do_Clustering.meanshift_labels)

# %%
GMM_Plot = False
if GMM_Plot:
    data = read_and_preprocess_data(input_dir, file)
    df_combined = generate_PCA_Data(data)

    Do_Clustering = C.Clustering(df_combined)
    Do_Clustering.perform_GMM(7)

    plot_UMAP(df_combined, Do_Clustering.Gaussian_labels)
